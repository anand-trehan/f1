# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv('races.csv')

# %%
df1.shape
# Out:
# (1026, 8)

# %%
df1.head(10)
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5       6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6       7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7       8  2009      8          9     British Grand Prix  2009-06-21
# 8       9  2009      9         20      German Grand Prix  2009-07-12
# 9      10  2009     10         11   Hungarian Grand Prix  2009-07-26
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# ...

# %%
df1.dtypes
# Out:
# raceId        int64
# year          int64
# round         int64
# circuitId     int64
# name         object
# date         object
# time         object
# url          object
# dtype: object

# %%
df1.sort_values(by=['year','round'],inplace=True)

# %%
df1.head(10)
# Out:
#      raceId  year  round  circuitId                name        date time  \
# 832     833  1950      1          9  British Grand Prix  1950-05-13   \N
# 833     834  1950      2          6   Monaco Grand Prix  1950-05-21   \N
# 834     835  1950      3         19    Indianapolis 500  1950-05-30   \N
# 835     836  1950      4         66    Swiss Grand Prix  1950-06-04   \N
# 836     837  1950      5         13  Belgian Grand Prix  1950-06-18   \N
# 837     838  1950      6         55   French Grand Prix  1950-07-02   \N
# 838     839  1950      7         14  Italian Grand Prix  1950-09-03   \N
# 824     825  1951      1         66    Swiss Grand Prix  1951-05-27   \N
# 825     826  1951      2         19    Indianapolis 500  1951-05-30   \N
# 826     827  1951      3         13  Belgian Grand Prix  1951-06-17   \N
#
#                                                    url
# 832  http://en.wikipedia.org/wiki/1950_British_Gran...
# ...

# %%
df1.tail(10)
# Out:
#       raceId  year  round  circuitId                         name        date  \
# 1016    1029  2019     20         18         Brazilian Grand Prix  2019-11-17
# 1017    1030  2019     21         24         Abu Dhabi Grand Prix  2019-12-01
# 1018    1041  2020      1         70          Austrian Grand Prix  2020-07-05
# 1019    1042  2020      2         70           Styrian Grand Prix  2020-07-12
# 1020    1043  2020      3         11         Hungarian Grand Prix  2020-07-19
# 1021    1044  2020      4          9           British Grand Prix  2020-08-02
# 1022    1045  2020      5          9  70th Anniversary Grand Prix  2020-08-09
# 1023    1046  2020      6          4           Spanish Grand Prix  2020-08-16
# 1024    1047  2020      7         13           Belgian Grand Prix  2020-08-30
# 1025    1048  2020      8         14           Italian Grand Prix  2020-09-06
#
#           time                                                url
# ...

# %%
df1.drop(['time'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#      raceId  year  round  circuitId                name        date  \
# 832     833  1950      1          9  British Grand Prix  1950-05-13
# 833     834  1950      2          6   Monaco Grand Prix  1950-05-21
# 834     835  1950      3         19    Indianapolis 500  1950-05-30
# 835     836  1950      4         66    Swiss Grand Prix  1950-06-04
# 836     837  1950      5         13  Belgian Grand Prix  1950-06-18
#
#                                                    url
# 832  http://en.wikipedia.org/wiki/1950_British_Gran...
# 833  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 834  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 835  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 836  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
df1.reset_index(inplace=True)

# %%
df1.head(10)
# Out:
#    index  raceId  year  round  circuitId                name        date  \
# 0    832     833  1950      1          9  British Grand Prix  1950-05-13
# 1    833     834  1950      2          6   Monaco Grand Prix  1950-05-21
# 2    834     835  1950      3         19    Indianapolis 500  1950-05-30
# 3    835     836  1950      4         66    Swiss Grand Prix  1950-06-04
# 4    836     837  1950      5         13  Belgian Grand Prix  1950-06-18
# 5    837     838  1950      6         55   French Grand Prix  1950-07-02
# 6    838     839  1950      7         14  Italian Grand Prix  1950-09-03
# 7    824     825  1951      1         66    Swiss Grand Prix  1951-05-27
# 8    825     826  1951      2         19    Indianapolis 500  1951-05-30
# 9    826     827  1951      3         13  Belgian Grand Prix  1951-06-17
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# ...

# %%
df1.drop(['index'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    raceId  year  round  circuitId                name        date  \
# 0     833  1950      1          9  British Grand Prix  1950-05-13
# 1     834  1950      2          6   Monaco Grand Prix  1950-05-21
# 2     835  1950      3         19    Indianapolis 500  1950-05-30
# 3     836  1950      4         66    Swiss Grand Prix  1950-06-04
# 4     837  1950      5         13  Belgian Grand Prix  1950-06-18
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
df1.tail()
# Out:
#       raceId  year  round  circuitId                         name        date  \
# 1021    1044  2020      4          9           British Grand Prix  2020-08-02
# 1022    1045  2020      5          9  70th Anniversary Grand Prix  2020-08-09
# 1023    1046  2020      6          4           Spanish Grand Prix  2020-08-16
# 1024    1047  2020      7         13           Belgian Grand Prix  2020-08-30
# 1025    1048  2020      8         14           Italian Grand Prix  2020-09-06
#
#                                                     url
# 1021  https://en.wikipedia.org/wiki/2020_British_Gra...
# 1022  https://en.wikipedia.org/wiki/70th_Anniversary...
# 1023  https://en.wikipedia.org/wiki/2020_Spanish_Gra...
# 1024  https://en.wikipedia.org/wiki/2020_Belgian_Gra...
# 1025  https://en.wikipedia.org/wiki/2020_Italian_Gra...

# %%
df1.rename(columns={'year':'season'},inplace=True)

# %%
df1.head()
# Out:
#    raceId  season  round  circuitId                name        date  \
# 0     833    1950      1          9  British Grand Prix  1950-05-13
# 1     834    1950      2          6   Monaco Grand Prix  1950-05-21
# 2     835    1950      3         19    Indianapolis 500  1950-05-30
# 3     836    1950      4         66    Swiss Grand Prix  1950-06-04
# 4     837    1950      5         13  Belgian Grand Prix  1950-06-18
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
df2=pd.read_csv('circuits.csv')

# %%
df2.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng alt  \
# 0  Australia -37.84970  144.96800  10
# 1   Malaysia   2.76083  101.73800  \N
# 2    Bahrain  26.03250   50.51060  \N
# 3      Spain  41.57000    2.26111  \N
# 4     Turkey  40.95170   29.40500  \N
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
df3=df1

# %%
df1.shape
# Out:
# (1026, 7)

# %%
df3.insert(7,'circuitRef'," ")

# %%
df3.insert(8,'latitude',"NaN")
df3.insert(9,'longitude',"NaN")
df3.insert(10,'alt',"NaN")
df3.insert(11,'country'," ")
df3.insert(12,'location'," ")

# %%
df3.head()
# Out:
#    raceId  season  round  circuitId                name        date  \
# 0     833    1950      1          9  British Grand Prix  1950-05-13
# 1     834    1950      2          6   Monaco Grand Prix  1950-05-21
# 2     835    1950      3         19    Indianapolis 500  1950-05-30
# 3     836    1950      4         66    Swiss Grand Prix  1950-06-04
# 4     837    1950      5         13  Belgian Grand Prix  1950-06-18
#
#                                                  url circuitRef latitude  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...                 NaN
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...                 NaN
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...                 NaN
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...                 NaN
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...                 NaN
#
#   longitude  alt country location
# 0       NaN  NaN
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# ...

# %%
df3.shape
# Out:
# (1026, 13)

# %%
len(df2)
# Out:
# 74

# %%
df2.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng alt  \
# 0  Australia -37.84970  144.96800  10
# 1   Malaysia   2.76083  101.73800  \N
# 2    Bahrain  26.03250   50.51060  \N
# 3      Spain  41.57000    2.26111  \N
# 4     Turkey  40.95170   29.40500  \N
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
df4=df3

# %%
#for i in range(len(df2))
temp=df2.iloc[0,:]
#df4.loc[(df4.circuitId==temp.circuitId),['circuitRef','latitude','longitude','alt','country','location']]=[temp.circuitRef,temp.lat,temp.lng,temp.alt,temp.country,temp.location]

# %%
temp.head()
# Out:
# circuitId                                  1
# circuitRef                       albert_park
# name          Albert Park Grand Prix Circuit
# location                           Melbourne
# country                            Australia
# Name: 0, dtype: object

# %%
temp.circuitId
# Out:
# 1

# %%
df4.loc[(df4.circuitId==temp.circuitId),['circuitRef','latitude','longitude','alt','country','location']]=[temp.circuitRef,temp.lat,temp.lng,temp.alt,temp.country,temp.location]

# %%
df4.loc[df4.circuitId==1]
# Out:
#      raceId  season  round  circuitId                   name        date  \
# 581     224    1996      1          1  Australian Grand Prix  1996-03-10
# 597     207    1997      1          1  Australian Grand Prix  1997-03-09
# 614     191    1998      1          1  Australian Grand Prix  1998-03-08
# 630     175    1999      1          1  Australian Grand Prix  1999-03-07
# 646     158    2000      1          1  Australian Grand Prix  2000-03-12
# 663     141    2001      1          1  Australian Grand Prix  2001-03-04
# 680     124    2002      1          1  Australian Grand Prix  2002-03-03
# 697     108    2003      1          1  Australian Grand Prix  2003-03-09
# 713      90    2004      1          1  Australian Grand Prix  2004-03-07
# 731      71    2005      1          1  Australian Grand Prix  2005-03-06
# 752      55    2006      3          1  Australian Grand Prix  2006-04-02
# 768      36    2007      1          1  Australian Grand Prix  2007-03-18
# ...

# %%
for i in range(len(df2)):
    temp=df2.iloc[i,:]
    df4.loc[(df4.circuitId==temp.circuitId),['circuitRef','latitude','longitude','alt','country','location']]=[temp.circuitRef,temp.lat,temp.lng,temp.alt,temp.country,temp.location]

# %%
df4.head(10)
# Out:
#    raceId  season  round  circuitId                name        date  \
# 0     833    1950      1          9  British Grand Prix  1950-05-13
# 1     834    1950      2          6   Monaco Grand Prix  1950-05-21
# 2     835    1950      3         19    Indianapolis 500  1950-05-30
# 3     836    1950      4         66    Swiss Grand Prix  1950-06-04
# 4     837    1950      5         13  Belgian Grand Prix  1950-06-18
# 5     838    1950      6         55   French Grand Prix  1950-07-02
# 6     839    1950      7         14  Italian Grand Prix  1950-09-03
# 7     825    1951      1         66    Swiss Grand Prix  1951-05-27
# 8     826    1951      2         19    Indianapolis 500  1951-05-30
# 9     827    1951      3         13  Belgian Grand Prix  1951-06-17
#
#                                                  url    circuitRef latitude  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...   silverstone  52.0786
# ...

# %%
df4.tail(10)
# Out:
#       raceId  season  round  circuitId                         name  \
# 1016    1029    2019     20         18         Brazilian Grand Prix
# 1017    1030    2019     21         24         Abu Dhabi Grand Prix
# 1018    1041    2020      1         70          Austrian Grand Prix
# 1019    1042    2020      2         70           Styrian Grand Prix
# 1020    1043    2020      3         11         Hungarian Grand Prix
# 1021    1044    2020      4          9           British Grand Prix
# 1022    1045    2020      5          9  70th Anniversary Grand Prix
# 1023    1046    2020      6          4           Spanish Grand Prix
# 1024    1047    2020      7         13           Belgian Grand Prix
# 1025    1048    2020      8         14           Italian Grand Prix
#
#             date                                                url  \
# 1016  2019-11-17  https://en.wikipedia.org/wiki/2019_Brazilian_G...
# 1017  2019-12-01  https://en.wikipedia.org/wiki/2019_Abu_Dhabi_G...
# ...

# %%
df4['alt'].value_counts()
# Out:
# \N    1002
# 10      24
# Name: alt, dtype: int64

# %%
df4.drop(['alt'],axis=1,inplace=True)

# %%
df4.head()
# Out:
#    raceId  season  round  circuitId                name        date  \
# 0     833    1950      1          9  British Grand Prix  1950-05-13
# 1     834    1950      2          6   Monaco Grand Prix  1950-05-21
# 2     835    1950      3         19    Indianapolis 500  1950-05-30
# 3     836    1950      4         66    Swiss Grand Prix  1950-06-04
# 4     837    1950      5         13  Belgian Grand Prix  1950-06-18
#
#                                                  url    circuitRef latitude  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...   silverstone  52.0786
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...        monaco  43.7347
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...  indianapolis   39.795
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...    bremgarten  46.9589
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...           spa  50.4372
#
#   longitude      country      location
# 0  -1.01694           UK   Silverstone
# ...

# %%
df4.drop(['name'],axis=1,inplace=True)

# %%
df4.head()
# Out:
#    raceId  season  round  circuitId        date  \
# 0     833    1950      1          9  1950-05-13
# 1     834    1950      2          6  1950-05-21
# 2     835    1950      3         19  1950-05-30
# 3     836    1950      4         66  1950-06-04
# 4     837    1950      5         13  1950-06-18
#
#                                                  url    circuitRef latitude  \
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...   silverstone  52.0786
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...        monaco  43.7347
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...  indianapolis   39.795
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...    bremgarten  46.9589
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...           spa  50.4372
#
#   longitude      country      location
# 0  -1.01694           UK   Silverstone
# 1   7.42056       Monaco   Monte-Carlo
# 2  -86.2347          USA  Indianapolis
# 3   7.40194  Switzerland          Bern
# ...

# %%
df4=df4[['season','round','circuitRef','circuitId','raceId','latitude','longitude','country','location','url']]

# %%
df4.head()
# Out:
#    season  round    circuitRef  circuitId  raceId latitude longitude  \
# 0    1950      1   silverstone          9     833  52.0786  -1.01694
# 1    1950      2        monaco          6     834  43.7347   7.42056
# 2    1950      3  indianapolis         19     835   39.795  -86.2347
# 3    1950      4    bremgarten         66     836  46.9589   7.40194
# 4    1950      5           spa         13     837  50.4372   5.97139
#
#        country      location  \
# 0           UK   Silverstone
# 1       Monaco   Monte-Carlo
# 2          USA  Indianapolis
# 3  Switzerland          Bern
# 4      Belgium           Spa
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
#df4.to_csv('race_data1.csv',index=False)

# %%
df5=pd.read_csv('results.csv')

# %%
df5.head(10)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
# 5         6      18         6              3      8    13        6
# 6         7      18         7              5     14    17        7
# 7         8      18         8              6      1    15        8
# 8         9      18         9              2      4     2       \N
# 9        10      18        10              7     12    18       \N
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# ...

# %%
df5.shape
# Out:
# (24660, 18)

# %%
df4.shape
# Out:
# (1026, 10)

# %%
df6=pd.read_csv('drivers.csv')

# %%
df6.head(10)
# Out:
#    driverId   driverRef number code   forename     surname         dob  \
# 0         1    hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI       Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS       Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO   Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV     Heikki  Kovalainen  1981-10-19
# 5         6    nakajima     \N  NAK     Kazuki    Nakajima  1985-01-11
# 6         7    bourdais     \N  BOU  Sébastien    Bourdais  1979-02-28
# 7         8   raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8         9      kubica     88  KUB     Robert      Kubica  1984-12-07
# 9        10       glock     \N  GLO       Timo       Glock  1982-03-18
#
#   nationality                                                url
# 0     British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...

# %%
df6.shape
# Out:
# (848, 9)

# %%
df5.insert(9,'driverRef',"NaN")
df5.insert(10,'dob',"NaN")
df5.insert(11,'nationality',"NaN")

# %%
df5.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder driverRef   ...    nationality points  laps  \
# 0            1              1       NaN   ...            NaN   10.0    58
# 1            2              2       NaN   ...            NaN    8.0    58
# 2            3              3       NaN   ...            NaN    6.0    58
# 3            4              4       NaN   ...            NaN    5.0    58
# 4            5              5       NaN   ...            NaN    4.0    58
#
#           time milliseconds fastestLap rank fastestLapTime fastestLapSpeed  \
# ...

# %%
df5.tail()
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 24655     24661    1042       847              3     63    11       16
# 24656     24662    1042       849              3      6    18       17
# 24657     24663    1042       839              4     31     5       \N
# 24658     24664    1042       844              6     16    14       \N
# 24659     24665    1042        20              6      5    10       \N
#
#       positionText  positionOrder driverRef   ...    nationality points  laps  \
# 24655           16             16       NaN   ...            NaN    0.0    69
# 24656           17             17       NaN   ...            NaN    0.0    69
# 24657            R             18       NaN   ...            NaN    0.0    25
# 24658            R             19       NaN   ...            NaN    0.0     4
# 24659            R             20       NaN   ...            NaN    0.0     1
#
# ...

# %%
for i in range(len(df6)):
    temp=df6.iloc[i,:]
    df5.loc[(df5.driverId==temp.driverId),['driverRef','dob','nationality']]=[temp.driverRef,temp.dob,temp.nationality]

# %%
df5.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder   driverRef   ...    nationality points  laps  \
# 0            1              1    hamilton   ...        British   10.0    58
# 1            2              2    heidfeld   ...         German    8.0    58
# 2            3              3     rosberg   ...         German    6.0    58
# 3            4              4      alonso   ...        Spanish    5.0    58
# 4            5              5  kovalainen   ...        Finnish    4.0    58
#
#           time milliseconds fastestLap rank fastestLapTime fastestLapSpeed  \
# ...

# %%
df5.insert(21,'season',"NaN")
df5.insert(22,'round',"NaN")
df5.insert(23,'circuitRef',"NaN")
df5.insert(24,'constructorRef',"NaN")

# %%
df4.head()
# Out:
#    season  round    circuitRef  circuitId  raceId latitude longitude  \
# 0    1950      1   silverstone          9     833  52.0786  -1.01694
# 1    1950      2        monaco          6     834  43.7347   7.42056
# 2    1950      3  indianapolis         19     835   39.795  -86.2347
# 3    1950      4    bremgarten         66     836  46.9589   7.40194
# 4    1950      5           spa         13     837  50.4372   5.97139
#
#        country      location  \
# 0           UK   Silverstone
# 1       Monaco   Monte-Carlo
# 2          USA  Indianapolis
# 3  Switzerland          Bern
# 4      Belgium           Spa
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
df4['round'].value_counts()
# Out:
# 1     71
# 2     71
# 3     71
# 4     71
# 5     71
# 6     71
# 7     71
# 8     69
# 9     63
# 10    58
# 11    54
# 12    50
# 13    48
# 14    47
# 15    45
# 16    40
# 17    22
# 18    14
# 19    11
# 20     5
# 21     3
# Name: round, dtype: int64

# %%
for i in range(len(df4)):
    temp=df4.iloc[i,:]
    df5.loc[(df5.raceId==temp.raceId),['season','round','circuitRef']]=[temp.season,temp.round,temp.circuitRef]

# %%
df5.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder   driverRef      ...       milliseconds  \
# 0            1              1    hamilton      ...            5690616
# 1            2              2    heidfeld      ...            5696094
# 2            3              3     rosberg      ...            5698779
# 3            4              4      alonso      ...            5707797
# 4            5              5  kovalainen      ...            5708630
#
#   fastestLap  rank  fastestLapTime fastestLapSpeed statusId season  \
# 0         39     2        1:27.452         218.300        1   2008
# ...

# %%
df5['round']
# Out:
# 0        <bound method Series.round of season          ...
# 1        <bound method Series.round of season          ...
# 2        <bound method Series.round of season          ...
# 3        <bound method Series.round of season          ...
# 4        <bound method Series.round of season          ...
# 5        <bound method Series.round of season          ...
# 6        <bound method Series.round of season          ...
# 7        <bound method Series.round of season          ...
# 8        <bound method Series.round of season          ...
# 9        <bound method Series.round of season          ...
# 10       <bound method Series.round of season          ...
# 11       <bound method Series.round of season          ...
# 12       <bound method Series.round of season          ...
# 13       <bound method Series.round of season          ...
# 14       <bound method Series.round of season          ...
# 15       <bound method Series.round of season          ...
# ...

# %%
df5['season']
# Out:
# 0        2008
# 1        2008
# 2        2008
# 3        2008
# 4        2008
# 5        2008
# 6        2008
# 7        2008
# 8        2008
# 9        2008
# 10       2008
# 11       2008
# 12       2008
# 13       2008
# 14       2008
# 15       2008
# 16       2008
# 17       2008
# 18       2008
# 19       2008
# 20       2008
# 21       2008
# 22       2008
# 23       2008
# 24       2008
# 25       2008
# 26       2008
# 27       2008
# 28       2008
# 29       2008
#          ...
# 24630    2020
# 24631    2020
# 24632    2020
# 24633    2020
# 24634    2020
# 24635    2020
# 24636    2020
# 24637    2020
# 24638    2020
# 24639    2020
# 24640    2020
# 24641    2020
# 24642    2020
# 24643    2020
# 24644    2020
# 24645    2020
# 24646    2020
# 24647    2020
# 24648    2020
# 24649    2020
# 24650    2020
# 24651    2020
# 24652    2020
# 24653    2020
# 24654    2020
# 24655    2020
# 24656    2020
# 24657    2020
# 24658    2020
# 24659    2020
# ...

# %%
temp1=df4.iloc[0,:]

# %%
temp1.round
# Out:
# <bound method Series.round of season                                                     1950
# round                                                         1
# circuitRef                                          silverstone
# circuitId                                                     9
# raceId                                                      833
# latitude                                                52.0786
# longitude                                              -1.01694
# country                                                      UK
# location                                            Silverstone
# url           http://en.wikipedia.org/wiki/1950_British_Gran...
# Name: 0, dtype: object>

# %%
temp1
# Out:
# season                                                     1950
# round                                                         1
# circuitRef                                          silverstone
# circuitId                                                     9
# raceId                                                      833
# latitude                                                52.0786
# longitude                                              -1.01694
# country                                                      UK
# location                                            Silverstone
# url           http://en.wikipedia.org/wiki/1950_British_Gran...
# Name: 0, dtype: object

# %%
for i in range(len(df4)):
    temp=df4.iloc[i,:]
    df5.loc[(df5.raceId==temp.raceId),['round']]=[temp['round']]

# %%
df5.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder   driverRef      ...       milliseconds  \
# 0            1              1    hamilton      ...            5690616
# 1            2              2    heidfeld      ...            5696094
# 2            3              3     rosberg      ...            5698779
# 3            4              4      alonso      ...            5707797
# 4            5              5  kovalainen      ...            5708630
#
#   fastestLap  rank  fastestLapTime fastestLapSpeed statusId season round  \
# ...

# %%
df5.dtypes
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# driverRef           object
# dob                 object
# nationality         object
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# season               int64
# round                int64
# circuitRef          object
# constructorRef      object
# dtype: object

# %%
df7=pd.read_csv('constructors.csv')

# %%
df7.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
for i in range(len(df7)):
    temp=df7.iloc[i,:]
    df5.loc[(df5.constructorId==temp.constructorId),['constructorRef']]=[temp.constructorRef]

# %%
df5.head(20)
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 2          3      18         3              3      7     7        3
# 3          4      18         4              4      5    11        4
# 4          5      18         5              1     23     3        5
# 5          6      18         6              3      8    13        6
# 6          7      18         7              5     14    17        7
# 7          8      18         8              6      1    15        8
# 8          9      18         9              2      4     2       \N
# 9         10      18        10              7     12    18       \N
# 10        11      18        11              8     18    19       \N
# 11        12      18        12              4      6    20       \N
# 12        13      18        13              6      2     4       \N
# ...

# %%
df5.isnull
# Out:
# <bound method DataFrame.isnull of        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# 5             6      18         6              3      8    13        6
# 6             7      18         7              5     14    17        7
# 7             8      18         8              6      1    15        8
# 8             9      18         9              2      4     2       \N
# 9            10      18        10              7     12    18       \N
# 10           11      18        11              8     18    19       \N
# 11           12      18        12              4      6    20       \N
# ...

# %%
df8=pd.read_csv('status.csv')

# %%
df8.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
df5.insert(25,'statusRef',"NaN")

# %%
for i in range(len(df8)):
    temp=df8.iloc[i,:]
    df5.loc[(df5.statusId==temp.statusId),['statusRef']]=[temp.status]

# %%
df5.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder   driverRef    ...    fastestLap rank  \
# 0            1              1    hamilton    ...            39    2
# 1            2              2    heidfeld    ...            41    3
# 2            3              3     rosberg    ...            41    5
# 3            4              4      alonso    ...            58    7
# 4            5              5  kovalainen    ...            43    1
#
#    fastestLapTime  fastestLapSpeed statusId season round   circuitRef  \
# 0        1:27.452          218.300        1   2008     1  albert_park
# ...

# %%
df5.drop(['number'],axis=1,inplace=True)
df5.drop(['position'],axis=1,inplace=True)
df5.drop(['milliseconds'],axis=1,inplace=True)

# %%
df5.head(10)
# Out:
#    resultId  raceId  driverId  constructorId  grid positionText  \
# 0         1      18         1              1     1            1
# 1         2      18         2              2     5            2
# 2         3      18         3              3     7            3
# 3         4      18         4              4    11            4
# 4         5      18         5              1     3            5
# 5         6      18         6              3    13            6
# 6         7      18         7              5    17            7
# 7         8      18         8              6    15            8
# 8         9      18         9              2     2            R
# 9        10      18        10              7    18            R
#
#    positionOrder   driverRef         dob nationality    ...      fastestLap  \
# 0              1    hamilton  1985-01-07     British    ...              39
# 1              2    heidfeld  1977-05-10      German    ...              41
# ...

# %%
df5.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'grid',
#        'positionText', 'positionOrder', 'driverRef', 'dob', 'nationality',
#        'points', 'laps', 'time', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'season', 'round', 'circuitRef',
#        'constructorRef', 'statusRef'],
#       dtype='object')

# %%
df5=df5[['season','round','circuitRef','raceId','resultId','driverRef','driverId','dob','nationality','constructorRef','constructorId','grid','positionText','positionOrder','points','laps','time','fastestLap','rank','fastestLapTime','fastestLapSpeed','statusId','statusRef']]

# %%
df5.head()
# Out:
#    season  round   circuitRef  raceId  resultId   driverRef  driverId  \
# 0    2008      1  albert_park      18         1    hamilton         1
# 1    2008      1  albert_park      18         2    heidfeld         2
# 2    2008      1  albert_park      18         3     rosberg         3
# 3    2008      1  albert_park      18         4      alonso         4
# 4    2008      1  albert_park      18         5  kovalainen         5
#
#           dob nationality constructorRef    ...     positionOrder  points  \
# 0  1985-01-07     British        mclaren    ...                 1    10.0
# 1  1977-05-10      German     bmw_sauber    ...                 2     8.0
# 2  1985-06-27      German       williams    ...                 3     6.0
# 3  1981-07-29     Spanish        renault    ...                 4     5.0
# 4  1981-10-19     Finnish        mclaren    ...                 5     4.0
#
#   laps         time  fastestLap  rank fastestLapTime fastestLapSpeed statusId  \
# ...

# %%
df5.sort_values(by=['season','round'],inplace=True)

# %%
df5.head()
# Out:
#        season  round   circuitRef  raceId  resultId    driverRef  driverId  \
# 20024    1950      1  silverstone     833     20025       farina       642
# 20025    1950      1  silverstone     833     20026      fagioli       786
# 20026    1950      1  silverstone     833     20027  reg_parnell       686
# 20027    1950      1  silverstone     833     20028    cabantous       704
# 20028    1950      1  silverstone     833     20029       rosier       627
#
#               dob nationality constructorRef    ...     positionOrder  points  \
# 20024  1906-10-30     Italian           alfa    ...                 1     9.0
# 20025  1898-06-09     Italian           alfa    ...                 2     6.0
# 20026  1911-07-02     British           alfa    ...                 3     4.0
# 20027  1904-10-08      French           lago    ...                 4     3.0
# 20028  1905-11-05      French           lago    ...                 5     2.0
#
# ...

# %%
df5.reset_index(inplace=True)

# %%
df5.drop(['index'],axis=1,inplace=True)

# %%
df5.head()
# Out:
#    season  round   circuitRef  raceId  resultId    driverRef  driverId  \
# 0    1950      1  silverstone     833     20025       farina       642
# 1    1950      1  silverstone     833     20026      fagioli       786
# 2    1950      1  silverstone     833     20027  reg_parnell       686
# 3    1950      1  silverstone     833     20028    cabantous       704
# 4    1950      1  silverstone     833     20029       rosier       627
#
#           dob nationality constructorRef    ...     positionOrder  points  \
# 0  1906-10-30     Italian           alfa    ...                 1     9.0
# 1  1898-06-09     Italian           alfa    ...                 2     6.0
# 2  1911-07-02     British           alfa    ...                 3     4.0
# 3  1904-10-08      French           lago    ...                 4     3.0
# 4  1905-11-05      French           lago    ...                 5     2.0
#
#   laps       time  fastestLap  rank fastestLapTime fastestLapSpeed statusId  \
# ...

# %%
df5.tail()
# Out:
#        season  round     circuitRef  raceId  resultId driverRef  driverId  \
# 24655    2020      2  red_bull_ring    1042     24661   russell       847
# 24656    2020      2  red_bull_ring    1042     24662    latifi       849
# 24657    2020      2  red_bull_ring    1042     24663      ocon       839
# 24658    2020      2  red_bull_ring    1042     24664   leclerc       844
# 24659    2020      2  red_bull_ring    1042     24665    vettel        20
#
#               dob nationality constructorRef        ...         positionOrder  \
# 24655  1998-02-15     British       williams        ...                    16
# 24656  1995-06-29    Canadian       williams        ...                    17
# 24657  1996-09-17      French        renault        ...                    18
# 24658  1997-10-16  Monegasque        ferrari        ...                    19
# 24659  1987-07-03      German        ferrari        ...                    20
#
# ...

# %%
df5.columns
# Out:
# Index(['season', 'round', 'circuitRef', 'raceId', 'resultId', 'driverRef',
#        'driverId', 'dob', 'nationality', 'constructorRef', 'constructorId',
#        'grid', 'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId',
#        'statusRef'],
#       dtype='object')

# %%
df9=pd.read_csv('pit_stops.csv')

# %%
df9.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
df9['stop'].value_counts()
# Out:
# 1    3613
# 2    2462
# 3    1048
# 4     284
# 5      73
# 6      15
# Name: stop, dtype: int64

# %%
df10=pd.read_csv('driver_standings.csv')

# %%
df10.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
df5.to_csv('results_data1.csv',index=False)

# %%
df5.drop(['fastestLap'],axis=1,inplace=True)
df5.drop(['rank'],axis=1,inplace=True)
df5.drop(['fastestLapTime'],axis=1,inplace=True)
df5.drop(['fastestLapSpeed'],axis=1,inplace=True)

# %%
df5.shape
# Out:
# (24660, 19)

# %%
df5.head()
# Out:
#    season  round   circuitRef  raceId  resultId    driverRef  driverId  \
# 0    1950      1  silverstone     833     20025       farina       642
# 1    1950      1  silverstone     833     20026      fagioli       786
# 2    1950      1  silverstone     833     20027  reg_parnell       686
# 3    1950      1  silverstone     833     20028    cabantous       704
# 4    1950      1  silverstone     833     20029       rosier       627
#
#           dob nationality constructorRef  constructorId  grid positionText  \
# 0  1906-10-30     Italian           alfa             51     1            1
# 1  1898-06-09     Italian           alfa             51     2            2
# 2  1911-07-02     British           alfa             51     4            3
# 3  1904-10-08      French           lago            154     6            4
# 4  1905-11-05      French           lago            154     9            5
#
#    positionOrder  points  laps       time  statusId statusRef
# ...

# %%
df5.to_csv('results_data2.csv',index=False)

# %%
df5.insert(19,'url',"NaN")

# %%
df4.head()
# Out:
#    season  round    circuitRef  circuitId  raceId latitude longitude  \
# 0    1950      1   silverstone          9     833  52.0786  -1.01694
# 1    1950      2        monaco          6     834  43.7347   7.42056
# 2    1950      3  indianapolis         19     835   39.795  -86.2347
# 3    1950      4    bremgarten         66     836  46.9589   7.40194
# 4    1950      5           spa         13     837  50.4372   5.97139
#
#        country      location  \
# 0           UK   Silverstone
# 1       Monaco   Monte-Carlo
# 2          USA  Indianapolis
# 3  Switzerland          Bern
# 4      Belgium           Spa
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4  http://en.wikipedia.org/wiki/1950_Belgian_Gran...

# %%
for i in range(len(df4)):
    temp=df4.iloc[i,:]
    df5.loc[(df5.raceId==temp.raceId),['url']]=[temp.url]

# %%
df5.head()
# Out:
#    season  round   circuitRef  raceId  resultId    driverRef  driverId  \
# 0    1950      1  silverstone     833     20025       farina       642
# 1    1950      1  silverstone     833     20026      fagioli       786
# 2    1950      1  silverstone     833     20027  reg_parnell       686
# 3    1950      1  silverstone     833     20028    cabantous       704
# 4    1950      1  silverstone     833     20029       rosier       627
#
#           dob nationality constructorRef  constructorId  grid positionText  \
# 0  1906-10-30     Italian           alfa             51     1            1
# 1  1898-06-09     Italian           alfa             51     2            2
# 2  1911-07-02     British           alfa             51     4            3
# 3  1904-10-08      French           lago            154     6            4
# 4  1905-11-05      French           lago            154     9            5
#
#    positionOrder  points  laps       time  statusId statusRef  \
# ...

# %%
df5.to_csv('results_data3.csv',index=False)
